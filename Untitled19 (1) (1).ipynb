# %%
class name:
    def display(self):
    print('class is called')
    
    obj = name()
    obj.display()
# Out:
#   Cell In[1], line 3
#     print('class is called')
#     ^
# IndentationError: expected an indented block after function definition on line 2

# %%
class student(object):
    def __init__(self,name,branch,year):
        self.name=name
        self.branch=branch
        self.year=year
        print("a student object is created")
        
        def print_details(self):
            print("name:",self.name)
            print("branch:",self.branch)
            print("year:",self.year)
            
ob1=student("himani","it",2024)

# %%
class himani(object):
    def __init__(self,name,age,salary):
        self.name=name
        self.age=age
        self.salary=salary
        print("i am it engineer and my salary is 50 thousand")
        
ob1=himani("vishal",25,1000000)

# %%
class a:
    def sayhi(self):
        print('i am in a')
        
class b(a):
    def sayhi(self):
        print("i am in b")
        
bobj=b()
bobj.sayhi()
# Out:
# i am in b

# %%
bobj=a()
bobj.sayhi()
# Out:
# i am in a

# %%
class ABC:
         def __init__(Self, name, age):
       
    Self.name = name
    Self.age = age
        
        def disp(Self):
            print(Self.name)
            
            def disp1(Self):
                print(Self.age)
                
    random = ABC ('himani',23) 
    random.disp()
# Out:
#   File <tokenize>:4
#     Self.name = name
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
class Dog:
  def __init__(self,color,age):
      self.color = color
      self.age = age

  def get_info(self):   # creating the method
      print("color of the dog is",self.color)
      print("age of the dog is",self.age)

# %%
dog1 = Dog("brown",5)


print(dog1.color)
print(dog1.age)


dog1.get_info()  # accessing the method

# %%
class ADD:
    def __init__(self,x,y):
        self.x = x
        self.y = y
        
        
        def show(self):
            print(f"sum is {4+5}")

calc = ADD

# %%
calc = ADD(4,3)
calc.show()

# %%
class Employee:
    def __init__(self, name, age):
        self.name =  name
        self.age = age
emp = Employee("himani",23)
emp.show()

# %%
class Student:
    def __init__(self, name, percentage):
        self.name = name
        self.percentage = percentage

    def show(self):
        print("Name is:", self.name, "and percentage is:", self.percentage)

stud = Student("Jessa", 80)
stud.show()

# %%
class Employee:
    depatment = "IT"

    def show(self):
        print("Department is ", self.depatment)

emp = Employee()
emp.show()

# %%
class student:
    depatment = "IT"

    def show(self):
        print("Department is ", self.depatment)

emp = student()
emp.show()

# %%
class himani:
    collage = "hr"
    
    def show(self):
        print("collage is", self.collage)
        
him = himani()
him.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([0,6])
ypoints = np.array([0,250])

plt.plot(xpoints, ypoints)
plt.show()

# %%
# Pyplot
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([4,6])
ypoints = np.array([50,250])

plt.plot(xpoints, ypoints)
plt.show()

# %%
#Plotiing (with lines)

import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
#Plotiing (with lines)

import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
#Plotiing (without lines)
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints,'o')
plt.show()

# %%
#Marker

import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '*')
plt.show()

# %%
# lines

import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([15, 0, 9, 1])

plt.plot(ypoints, linestyle = 'dashed')
plt.show()

# %%
#lables

import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
#lables

import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 125])
y = np.array([240,330])

plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
#grid

import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid()

plt.show()

# %%
#grid

import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 125])
y = np.array([240, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid()

plt.show()

# %%
#Subplot

import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
#Subplot

import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0,7, 9, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
#Scatter
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %%
#Barplot
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
#Barplot
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["o", "B", "L", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
# HIstogram
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %%
#Pie Chart
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %%
#Pie Chart
import matplotlib.pyplot as plt
import numpy as np#Pie Chart
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %%
"""Seaborn"""
  #Violen Plot
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import matplotlib.image as mpimg

group=["Group-A" ,"Group-A" ,"Group-B","Group-B" ,"Group-C","Group-C","Group-D","Group-D"]
values=[75,45,47 , 56 ,59, 67 ,89 ,120]

sns.violinplot(x=group , y=values)
plt.show()

# %%
"""Seaborn"""
  #Violen Plot
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import matplotlib.image as mpimg

group=["Group-A" ,"Group-A" ,"Group-B","Group-B" ,"Group-C","Group-C","Group-D","Group-D"]
values=[75,45,47 , 56 ,59, 67 ,89 ,120]

sns.violinplot(x=group , y=values)
plt.show()

# %%
#Boxplot
import pandas as pd
import matplotlib.pyplot as plt

# Create a sample DataFrame
df = pd.DataFrame({'A': [1, 2, 3, 4, 5],
                   'B': [10, 20, 30, 40, 50]})

# Plot the box plots
df.plot(kind='box')

# Customize the plot as needed
plt.title('Box Plots of A and B')
plt.xlabel('Variable')
plt.ylabel('Value')

# Show the plot
plt.show()

# %%
#Area Plot

month=["Jan","Feb","Mar","Apr"]
plant1=[ 30,23,45,67]
plant2=[20,45,67,89]
plant3=[45,56,78,90]

plt.fill_between(month , plant1,color="Blue",alpha=0.5,label="Plant1")
plt.fill_between(month , plant2,color="Pink",alpha=1,label="Plant2")
plt.fill_between(month , plant3,color="Grey",alpha=0.4,label="Plant3")

plt.legend(title="Plant details",loc="upper left")
plt.grid(True)
plt.show()

# %%
#Density Plot

import seaborn as sns
import matplotlib.pyplot as plt

# Load the iris dataset (replace with your own data)
df = sns.load_dataset('iris')

# Create a density plot
sns.kdeplot(df['sepal_width'])
plt.show()

# %%
#Density Plot

import seaborn as sns
import matplotlib.pyplot as plt

# Load the iris dataset (replace with your own data)
df = sns.load_dataset('iris')

# Create a density plot
sns.kdeplot(df['sepal_width'])
plt.show()

# %%
class calculator:
    def __init__(self,x,y):
        self.x=x
        self.y=y
        
        def add(self):
            print(f' sum is {self.x+self.y}')
            
            def mult(self):
                print(f'product is {self.x+self.y}')
                
                def subt(self):
                    print(f'difference is{self.x+self.y}')

# %%
obj=calculator(5,6)
obj.()
# Out:
#   Cell In[24], line 2
#     obj.()
#         ^
# SyntaxError: invalid syntax

# %%
obj1=calculator(10,5)
obj1.subt()

# %%
class abc:
    def __init__(self,name,age):
        self.a=name
        self.b=age
        def disp(self):
            print(self.a, self.b)

# %%
obj=abc('rinku',30)

# %%
obj.disp()

# %%
class Dog:
    def __init__(self,name,age,bread):
        self.name=name
        self.age=age
        self.bread=bread
        
        def bark(self):
            print(f'{self.name} says bow bow!')
            
            def display(self):
                print(f'{self.name} is {self.age} years old and is a {self.bread}')

# %%
mydog=Dog('jimmy',5,'buldog')

# %%
mydog.bark()
mydog.display()

# %%
class Dog:

    # class attribute
    attr1 = "mammal"

    # Instance attribute
    def __init__(self, name):
        self.name = name

# Driver code
# Object instantiation
Rodger = Dog("Rodger")
Tommy = Dog("Tommy")

# Accessing class attributes
print("Rodger is a {}".format(Rodger.__class__.attr1))
print("Tommy is also a {}".format(Tommy.__class__.attr1))

# Accessing instance attributes
print("My name is {}".format(Rodger.name))
print("My name is {}".format(Tommy.name))

# %%
class Dog:

    # class attribute
    attr1 = "mammal"

    # Instance attribute
    def __init__(self, name):
        self.name = name
        
    def speak(self):
        print("My name is {}".format(self.name))

# Driver code
# Object instantiation
Rodger = Dog("Rodger")
Tommy = Dog("Tommy")

# %%
Rodger.speak()
Tommy.speak()

# %%
class Employee:
    # class variables
    company_name = 'ABC Company'

    # constructor to initialize the object
    def __init__(self, name, salary):
        # instance variables
        self.name = name
        self.salary = salary

    # instance method
    def show(self):
        print('Employee:', self.name, self.salary, self.company_name)

# create first object
emp1 = Employee("Harry", 12000)
emp1.show()

# create second object
emp2 = Employee("Emma", 10000)
emp2.show()

# %%
class car:
    def __init__(self,model,colour,speed):
        self.model=model
        self.colour=colour
        self.speed=speed
        
        def display(self):
            print(f'{self.model}is{self.colour}and runs{self.speed}')
            
obj = car('BMW','black',150)
obj.display()

# %%
# single

# %%
class parent:
    def __init__(self):
        self.name="peter"
        
class child(parent):
    def display(self):
        print(self.name)
        
obj=child()
obj.display()

# %%
class father:
    def __init__(self):
        self.name="himani"
        
class son(father):
    def display(self):
        print(self.name)
        
obj=son()
obj.display()

# %% [markdown]
# class mother:
#     def __init__(self):
#         self.name="hardik"
#
# class son(mother):
#     def display(self):
#         print(self.name)
#
# obj=son()
# obj.display()

# %%
# multilevel

# %%
class parent:
    def __init__(self):
        self.name="himani"

class child(parent):
    def __init__(self):
        parent.__init__(self)
        self.age=27
        
        def display(self):
            print(self.name,self.age)
            
class child2(child):
    def __init__(self):
        child.__init__(self)
        self.prof="Engineer"
        
        def display(self):
            print(self.name,self.age,self.prof)

# %%
obj=child()
obj.display()

# %%
class parent:
    def __init__(self):
        self.name="peter"
        
class child(parent):
    def display(self):
        print(self.name)
        
obj=child()
obj.display()

# %%
#encapsulation

# %%
class Myclass:
    def __init__(self,color):
        self.pub_mem='I am a public member'
        self.color= color
        
obj=Myclass('Red')
obj.pub_mem

# %%
class Myteacher:
    def __init__(self,color):
        self.him_cha='i am himani chauhan'
        self.color= color
        
obj=Myteacher('Red')
obj.him_cha

# %%
class priv:
    def __init__(self,balance):
        self.priv_mem="i am a private member"
        self.balance= balance 
        
class rock(priv):
    def disp(self):
        print(self.balance)
        
obj=priv(1234)
obj.priv_mem

obj1=rock(1234)
obj1.disp()

# %%
# oops hadson

# %%
import math
def factor(num):
    return math.factorial(num)

# %%
factor(5)

# %%
factor(9)

# %%
factor(3)

# %%
factor(6)

# %%
def check_string():
    str1=input("enter the string:")
    if 's' in str1 or 'S' in str1:
    print("The string is containing the letter s")

    else:
        print("The string does not contain  the letter s")
        
    
Check_string()

# %%
class student:
    def fun1(self):
        n=int(input('enter a string'))
        def message(self):
            k=self.fun1()
            return k

# %%
obj=student()
obj.message()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 2
#       1 obj=student()
# ----> 2 obj.message()
#
# AttributeError: 'student' object has no attribute 'message'
